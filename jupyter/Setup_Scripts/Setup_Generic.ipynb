# %%
import chipwhisperer as cw

try:
    if not scope.connectStatus:
        scope.con()
except NameError:
    scope = cw.scope()

try:
    if SS_VER == "SS_VER_2_1":
        target_type = cw.targets.SimpleSerial2
    elif SS_VER == "SS_VER_2_0":
        raise OSError("SS_VER_2_0 is deprecated. Use SS_VER_2_1")
    else:
        target_type = cw.targets.SimpleSerial
except:
    SS_VER="SS_VER_1_1"
    target_type = cw.targets.SimpleSerial

try:
    target = cw.target(scope, target_type)
except:
    print("INFO: Caught exception on reconnecting to target - attempting to reconnect to scope first.")
    print("INFO: This is a work-around when USB has died without Python knowing. Ignore errors above this line.")
    scope = cw.scope()
    target = cw.target(scope, target_type)

print("INFO: Found ChipWhisperer😍")

if "STM" in PLATFORM or PLATFORM == "CWLITEARM" or PLATFORM == "CWNANO":
    prog = cw.programmers.STM32FProgrammer
elif PLATFORM == "CW303" or PLATFORM == "CWLITEXMEGA":
    prog = cw.programmers.XMEGAProgrammer
elif "neorv32" in PLATFORM.lower():
    prog = cw.programmers.NEORV32Programmer
elif "SAM4S" in PLATFORM or PLATFORM == "CWHUSKY":
    prog = cw.programmers.SAM4SProgrammer
else:
    prog = None

import time
time.sleep(0.05)
scope.default_setup()

if PLATFORM == "CW308_RP2040":
    scope.clock.clkgen_freq = 12e6
    scope.io.hs2 = 'clkgen'
    
def reset_target(scope):
    if PLATFORM == "CW303" or PLATFORM == "CWLITEXMEGA":
        scope.io.pdic = 'low'
        time.sleep(0.1)
        scope.io.pdic = 'high_z' #XMEGA doesn't like pdic driven high
        time.sleep(0.1) #xmega needs more startup time
    elif "neorv32" in PLATFORM.lower():
        raise IOError("Default iCE40 neorv32 build does not have external reset - reprogram device to reset")
    elif PLATFORM == "CW308_SAM4S" or PLATFORM == "CWHUSKY":
        scope.io.nrst = 'low'
        time.sleep(0.25)
        scope.io.nrst = 'high_z'
        time.sleep(0.25)
    elif PLATFORM == "CW308_RP2040":
        scope.io.nrst = 'low'    # drives RP2040 RUN pin low
        time.sleep(0.1)
        scope.io.nrst = 'high_z'
        time.sleep(0.1)
    else:  
        scope.io.nrst = 'low'
        time.sleep(0.05)
        scope.io.nrst = 'high_z'
        time.sleep(0.05)

reset_target(scope)
time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5         scope.con()
#       6 except NameError:
# ----> 7     scope = cw.scope()
#       8
#
# NameError: name 'scope' is not defined
#
# During handling of the above exception, another exception occurred:
#
# USBErrorIO                                Traceback (most recent call last)
# Cell In[1], line 7
#       3 try:
#       4     if not scope.connectStatus:
#       5         scope.con()
#       6 except NameError:
# ----> 7     scope = cw.scope()
#       8
#       9 try:
#      10     if SS_VER == "SS_VER_2_1":
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/__init__.py:400, in scope(scope_type, name, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     398 rtn : scopes.ScopeTypes = scope_type()
#     399 try:
# --> 400     rtn.con(**kwargs)
#     401 except IOError:
#     402     scope_logger.error("ChipWhisperer error state detected. Resetting and retrying connection...")
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/capture/scopes/OpenADC.py:667, in OpenADC.con(self, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     664 self.gain = GainSettings(self.sc, self.adc)
#     666 self.pll = None
# --> 667 self.advancedSettings = ChipWhispererExtra.ChipWhispererExtra(cwtype, self.scopetype, self.sc)
#     668 self.glitch_drp1 = None
#     669 self.glitch_drp2 = None
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/capture/scopes/cwhardware/ChipWhispererExtra.py:2244, in ChipWhispererExtra.__init__(self, cwtype, scope, oa)
#    2242 self.enableGlitch = True
#    2243 if self.enableGlitch:
# -> 2244     self.glitch = ChipWhispererGlitch.ChipWhispererGlitch(cwtype, scope, oa)
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:762, in ChipWhispererGlitch.__init__(self, cwtype, scope, oa)
#     759     self._max_offset = self.glitchPR.limitList[1][1] / 2.55
#     761 if not self._is_husky:
# --> 762     self.setOpenADC(oa)
#     763 self.glitchSettings = GlitchSettings(self)
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:777, in ChipWhispererGlitch.setOpenADC(self, oa)
#     774         return
#     776     # Reset FPGA back to defaults in case previous bitstreams loaded
# --> 777     self.updatePartialReconfig()
#     778 self.oa = oa
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:798, in ChipWhispererGlitch.updatePartialReconfig(self, _)
#     795 bs = self.glitchPR.getPartialBitstream([self._width, self._offset])
#     797 if self.prEnabled:
# --> 798     self.prCon.program(bs)
#     799     if self.oa is not None:
#     800         self.resetDCMs()
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/capture/scopes/cwhardware/PartialReconfiguration.py:167, in PartialReconfigConnection.program(self, cfgdata)
#     163     dataarray.append(msb)
#     164     dataarray.append(lsb)
# --> 167 self.oa.sendMessage(self.CODE_WRITE, self.reconfig, dataarray, Validate=False)
#     169 # stat = self.oa.sendMessage(self.CODE_READ, self.reconfig, Validate=False, maxResp=1)
#     170 # print "%02x" % stat[0]
#     171
#     172 # Write Data
#     173 self.oa.sendMessage(self.CODE_WRITE, self.reconfig, [0x1A], Validate=False)
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/capture/scopes/_OpenADCInterface.py:291, in OpenADCInterface.sendMessage(self, mode, address, payload, Validate, maxResp, readMask)
#     289 if mode != CODE_WRITE:
#     290     return self.msg_read(address, maxResp)
# --> 291 self.msg_write(address, payload)
#     292 if Validate:
#     293     self.msg_validate(address, payload, read_mask=readMask)
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/capture/scopes/_OpenADCInterface.py:247, in OpenADCInterface.msg_write(self, address, payload)
#     244 address = self._address_str2int(address)
#     245 if self._serial_not_stream:
#     246     # Write output to memory
# --> 247     self.serial.cmdWriteMem(address, payload)
#     248 else:
#     249     self._send_msg_hdr(CODE_WRITE, address, len(payload))
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/hardware/naeusb/naeusb.py:897, in NAEUSB.cmdWriteMem(self, addr, data)
#     891 def cmdWriteMem(self, addr : int, data : bytearray):
#     892     """
#     893     Send command to write memory over external memory interface to FPGA. Automatically
#     894     decides to use control-transfer or bulk-endpoint transfer based on data length.
#     895     """
# --> 897     return self.usbserializer.cmdWriteMem(addr, data)
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/hardware/naeusb/naeusb.py:668, in NAEUSB_Backend.cmdWriteMem(self, addr, data)
#     666     self._cmd_writemem_ctrl(addr, pload)
#     667 else:
# --> 668     self._cmd_writemem_bulk(addr, pload)
#     670 naeusb_logger.debug("FPGA_WRITE: bulk: {}, addr: {:08X}, dlen: {:08X}, response: {}"\
#     671     .format("yes" if len(pload) >= NAEUSB_CTRL_IO_THRESHOLD else "no", addr, len(pload), data))
#     673 return None
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/hardware/naeusb/naeusb.py:657, in NAEUSB_Backend._cmd_writemem_bulk(self, addr, data)
#     654 """Writes data to the external memory interface via the bulk-transfer endpoint.
#     655 """
#     656 self._cmd_ctrl_send_header(addr, len(data), self.CMD_WRITEMEM_BULK)
# --> 657 self._bulk_write(data, None)
#
# File /venv/lib/python3.12/site-packages/chipwhisperer/hardware/naeusb/naeusb.py:590, in NAEUSB_Backend._bulk_write(self, data, timeout)
#     587 """Writes data over the bulk-transfer endpoint.
#     588 """
#     589 timeout = self._get_timeout(timeout)
# --> 590 self.handle.bulkWrite(self.wep, data, timeout)
#
# File /venv/lib/python3.12/site-packages/usb1/__init__.py:1465, in USBDeviceHandle.bulkWrite(self, endpoint, data, timeout)
#    1463 # pylint: enable=undefined-variable
#    1464 data, _ = create_initialised_buffer(data)
# -> 1465 return self._bulkTransfer(endpoint, data, sizeof(data), timeout)
#
# File /venv/lib/python3.12/site-packages/usb1/__init__.py:1434, in USBDeviceHandle._bulkTransfer(self, endpoint, data, length, timeout)
#    1432 transferred = c_int()
#    1433 try:
# -> 1434     mayRaiseUSBError(libusb1.libusb_bulk_transfer(
#    1435         self.__handle, endpoint, data, length, byref(transferred), timeout,
#    1436     ))
#    1437 # pylint: disable=undefined-variable
#    1438 except USBErrorTimeout as exception:
#    1439     # pylint: enable=undefined-variable
#
# File /venv/lib/python3.12/site-packages/usb1/__init__.py:129, in mayRaiseUSBError(value, __raiseUSBError)
#     123 def mayRaiseUSBError(
#     124         value,
#     125         # Avoid globals lookup on call to work during interpreter shutdown.
#     126         __raiseUSBError=raiseUSBError,
#     127     ):
#     128     if value < 0:
# --> 129         __raiseUSBError(value)
#     130     return value
#
# File /venv/lib/python3.12/site-packages/usb1/__init__.py:121, in raiseUSBError(value, __STATUS_TO_EXCEPTION_DICT, __USBError)
#     115 def raiseUSBError(
#     116         value,
#     117         # Avoid globals lookup on call to work during interpreter shutdown.
#     118         __STATUS_TO_EXCEPTION_DICT=STATUS_TO_EXCEPTION_DICT,
#     119         __USBError=USBError,
#     120     ): # pylint: disable=dangerous-default-value
# --> 121     raise __STATUS_TO_EXCEPTION_DICT.get(value, __USBError)(value)
#
# USBErrorIO: LIBUSB_ERROR_IO [-1]
